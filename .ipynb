# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 26.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 26.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('C:\\Users\\cw\\Desktop\\cells\\Social_Network_Ads - Social_Network_Ads.csv')

# %%
df.head(5)
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Female    204
# Male      196
# Name: count, dtype: int64

# %%
x=df.drop(columns=['Purchased'])
y=df['Purchased']

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb= LabelEncoder()

# %%
x_train=lb.fit_transform(x['Gender'])

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x_train,y,test_size=0.2,random_state=42)

# %%
 np.round(x_train.describe(),2)

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()

# %%
x_train_sc=sc.fit_transform(x_train)

# %%
x_train_new=pd.DataFrame(x_train_sc,columns=x_train.columns)

# %%
np.round(x_train.describe(),2)
# Out:
#            0
# count  320.0
# mean     0.5
# std      0.5
# min      0.0
# 25%      0.0
# 50%      0.5
# 75%      1.0
# max      1.0

# %%
from sklearn.preprocessing import OrdinalEncoder
oe=OrdinalEncoder()

# %%
df_ar=oe.fit_transform(df)

# %%
df_new=pd.DataFrame(df_ar,columns=df.columns)

# %%
df_new
# Out:
#      User ID  Gender   Age  EstimatedSalary  Purchased
# 0       97.0     1.0   1.0              4.0        0.0
# 1      392.0     1.0  17.0              5.0        0.0
# 2      155.0     0.0   8.0             26.0        0.0
# 3       64.0     0.0   9.0             39.0        0.0
# 4      382.0     1.0   1.0             57.0        0.0
# ..       ...     ...   ...              ...        ...
# 395    196.0     0.0  28.0             24.0        1.0
# 396    220.0     1.0  33.0              8.0        1.0
# 397    130.0     0.0  32.0              5.0        1.0
# 398    305.0     1.0  18.0             17.0        0.0
# 399     45.0     0.0  31.0             20.0        1.0
#
# [400 rows x 5 columns]

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
ohe=OneHotEncoder(drop='first',sparse_output=False,dtype=np.int32)

# %%
df.isnull().sum()
# Out:
# User ID            0
# Gender             0
# Age                0
# EstimatedSalary    0
# Purchased          0
# dtype: int64

# %%
df=df.drop(columns=['Age'])

# %%
ohe=fit_transform(df[['Gender']])

# %%
pd.get_dummies(df,columns=['Gender'],drop_first=True)
# Out:
#       User ID  Age  EstimatedSalary  Purchased  Gender_Male
# 0    15624510   19            19000          0         True
# 1    15810944   35            20000          0         True
# 2    15668575   26            43000          0        False
# 3    15603246   27            57000          0        False
# 4    15804002   19            76000          0         True
# ..        ...  ...              ...        ...          ...
# 395  15691863   46            41000          1        False
# 396  15706071   51            23000          1         True
# 397  15654296   50            20000          1        False
# 398  15755018   36            33000          0         True
# 399  15594041   49            36000          1        False
#
# [400 rows x 5 columns]

# %%
 a=a.astype(int)

# %%
a
